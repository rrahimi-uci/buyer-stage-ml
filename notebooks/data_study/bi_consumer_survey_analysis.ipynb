# %%
# %run bi_ml_utilities.ipynb
# Out:
# ...
#     100% |████████████████████████████████| 51kB 3.1MB/s ta 0:00:011
# ...
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
#     100% |████████████████████████████████| 142.8MB 366kB/s eta 0:00:011
# ...
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
df_survey = pd.read_csv('Consumer_Stage_Survey_Data_9.24.2019.csv')

# %%
df_survey.head(5)
# Out:
#    Unnamed: 0            StartDate              EndDate         Status  \
# 0           0           Start Date             End Date  Response Type
# 1           1  2019-09-05 16:19:36  2019-09-05 16:20:57     IP Address
# 2           2  2019-09-10 16:10:51  2019-09-10 16:14:13     IP Address
# 3           3  2019-09-10 16:17:54  2019-09-10 16:19:24     IP Address
# 4           4  2019-09-10 16:17:50  2019-09-10 16:20:18     IP Address
#
#         IPAddress  Progress  Duration (in seconds)  Finished  \
# 0      IP Address  Progress  Duration (in seconds)  Finished
# 1   209.74.103.33       100                     80      True
# 2  99.123.204.252       100                    201      True
# 3    70.162.97.89       100                     90      True
# 4     68.97.58.22       100                    148      True
#
#           RecordedDate         ResponseId  ...         Q33  \
# 0        Recorded Date        Response ID  ...  Are youâ€¦
# ...
