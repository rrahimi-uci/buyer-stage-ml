# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.read_csv('df_sampled.csv')
df = df.drop(df.columns[0], axis = 1)
df = df.fillna(0)

# %%
summary = df.describe()

# %%
summary.shape
# Out:
# (8, 228)

# %%
lst_dwell_time = ['average_ldp_dwell_time_seconds_001' , 'total_ldp_dwell_time_seconds_001' , 'median_ldp_dwell_time_seconds_001' , 'total_srp_dwell_time_seconds_001' , 'average_srp_dwell_time_seconds_001' , 
'median_srp_dwell_time_seconds_001' , 'total_lead_dwell_time_seconds_001' , 'average_lead_dwell_time_seconds_001' , 'median_lead_dwell_time_seconds_001' ,
                  'average_ldp_dwell_time_seconds_007' , 'total_ldp_dwell_time_seconds_007' , 'median_ldp_dwell_time_seconds_007' , 'total_srp_dwell_time_seconds_007' , 'average_srp_dwell_time_seconds_007' , 
'median_srp_dwell_time_seconds_007' , 'total_lead_dwell_time_seconds_007' , 'average_lead_dwell_time_seconds_007' , 'median_lead_dwell_time_seconds_007' , 
                  'average_ldp_dwell_time_seconds_030' , 'total_ldp_dwell_time_seconds_030' , 'median_ldp_dwell_time_seconds_030' , 'total_srp_dwell_time_seconds_030' , 'average_srp_dwell_time_seconds_030' , 
'median_srp_dwell_time_seconds_030' , 'total_lead_dwell_time_seconds_030' , 'average_lead_dwell_time_seconds_030' , 'median_lead_dwell_time_seconds_030' , 
                  'average_ldp_dwell_time_seconds_060' , 'total_ldp_dwell_time_seconds_060' , 'median_ldp_dwell_time_seconds_060' , 'total_srp_dwell_time_seconds_060' , 'average_srp_dwell_time_seconds_060' , 
'median_srp_dwell_time_seconds_060' , 'total_lead_dwell_time_seconds_060' , 'average_lead_dwell_time_seconds_060' , 'median_lead_dwell_time_seconds_060' , 
                  'average_ldp_dwell_time_seconds_090' , 'total_ldp_dwell_time_seconds_090' , 'median_ldp_dwell_time_seconds_090' , 'total_srp_dwell_time_seconds_090' , 'average_srp_dwell_time_seconds_090' , 
'median_srp_dwell_time_seconds_090' , 'total_lead_dwell_time_seconds_090' , 'average_lead_dwell_time_seconds_090' , 'median_lead_dwell_time_seconds_090' ] 


lst_001_007_030 = ['median_ldp_page_views_001','median_ldp_page_views_007','median_ldp_page_views_030',
      'median_ldp_dwell_time_seconds_001','median_ldp_dwell_time_seconds_007','median_ldp_dwell_time_seconds_030', 
       'median_distinct_listings_viewed_001', 'median_distinct_listings_viewed_007','median_distinct_listings_viewed_030', 
       'median_searches_001', 'median_searches_007','median_searches_030',
       'total_saved_listings_001','total_saved_listings_007','total_saved_listings_030',
       'total_saved_searches_001','total_saved_searches_007','total_saved_searches_030',
      'submitted_leads_for_sale_001','submitted_leads_for_sale_007','submitted_leads_for_sale_030']


lst_030_060_090 = ['median_ldp_page_views_030','median_ldp_page_views_060','median_ldp_page_views_090',
      'median_ldp_dwell_time_seconds_030','median_ldp_dwell_time_seconds_060', 'median_ldp_dwell_time_seconds_090', 
       'median_distinct_listings_viewed_030', 'median_distinct_listings_viewed_060', 'median_distinct_listings_viewed_090', 
       'median_searches_030', 'median_searches_060','median_searches_090',
       'total_saved_listings_030','total_saved_listings_060', 'total_saved_listings_090', 
       'total_saved_searches_030','total_saved_searches_060','total_saved_searches_090',
      'submitted_leads_for_sale_030','submitted_leads_for_sale_060','submitted_leads_for_sale_090']


lst_001_007_030_060_090 = ['median_ldp_page_views_001','median_ldp_page_views_007','median_ldp_page_views_030', 'median_ldp_page_views_060','median_ldp_page_views_090',
      'median_ldp_dwell_time_seconds_001','median_ldp_dwell_time_seconds_007','median_ldp_dwell_time_seconds_030', 'median_ldp_dwell_time_seconds_060', 'median_ldp_dwell_time_seconds_090', 
       'median_distinct_listings_viewed_001', 'median_distinct_listings_viewed_007','median_distinct_listings_viewed_030', 'median_distinct_listings_viewed_060', 'median_distinct_listings_viewed_090', 
       'median_searches_001', 'median_searches_007','median_searches_030', 'median_searches_060','median_searches_090',
       'total_saved_listings_001','total_saved_listings_007','total_saved_listings_030', 'total_saved_listings_060', 'total_saved_listings_090', 
       'total_saved_searches_001','total_saved_searches_007','total_saved_searches_030', 'total_saved_searches_060','total_saved_searches_090',
      'submitted_leads_for_sale_001','submitted_leads_for_sale_007','submitted_leads_for_sale_030', 'submitted_leads_for_sale_060','submitted_leads_for_sale_090']

df_important_attributes_001_007_030 = df[lst_001_007_030]
df_important_attributes_030_060_090 = df[lst_030_060_090]
df_important_attributes_001_007_030_060_090 = df[lst_001_007_030_060_090]
df_dwell_time = df[lst_dwell_time]

# %%
median_df_important_attributes_001_007_030 = df_important_attributes_001_007_030.median()
median_df_important_attributes_030_060_090 = df_important_attributes_030_060_090.median()

x = median_df_important_attributes_001_007_030[columns = ('median_ldp_page_views_001', 'median_ldp_page_views_007', 'median_ldp_page_views_030')]
y = median_df_important_attributes_001_007_030[columns  = ('submitted_leads_for_sale_001', 'submitted_leads_for_sale_001', 'submitted_leads_for_sale_001')]
plt.plot(x, y )
# Out:
#   File "<ipython-input-61-9454213aeb96>", line 4
#     x = median_df_important_attributes_001_007_030[columns = ('median_ldp_page_views_001', 'median_ldp_page_views_007', 'median_ldp_page_views_030')]
#                                                            ^
# SyntaxError: invalid syntax

# %%
#Almost There is No correlation among attributes
corr = df_important_attributes_001_007_030.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col1 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col2 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col3 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_48b74736_4c2c_11ea_96d5_61aea13958cdrow0_col6 {
#             background-color:  #5572df;
#             color:  #000000;
# ...

# %%
#Almost There is No correlation among attributes
corr = df_important_attributes_030_060_090.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col1 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col2 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col5 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_4afd6f2a_4c2c_11ea_96d5_61aea13958cdrow0_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
# ...

# %%
#Almost There is No correlation among attributes
corr = df_dwell_time.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col1 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col2 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4ca44664_4c2c_11ea_96d5_61aea13958cdrow0_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
# ...

# %%
df_dwell_time.describe()[:][:]
# Out:
#        average_ldp_dwell_time_seconds_001  total_ldp_dwell_time_seconds_001  \
# count                          976.000000                        976.000000
# mean                            38.442886                         62.496926
# std                            119.215719                        180.244449
# min                              1.000000                          1.000000
# 25%                              4.000000                          5.000000
# 50%                             10.000000                         14.000000
# 75%                             27.000000                         39.000000
# max                           1798.000000                       1798.000000
#
#        median_ldp_dwell_time_seconds_001  total_srp_dwell_time_seconds_001  \
# count                         976.000000                        976.000000
# mean                           39.905738                        270.757172
# ...

# %% [markdown]
# ## It shows high correleation between 60 and 90 (>0.92) among important attributes which means 60 days history could be enough for modeling

# %%
from sklearn import preprocessing
min_max_normalized_df_important_attributes_001_007_030 = preprocessing.normalize(df_important_attributes_001_007_030)
tmp_001_007_0030 = pd.DataFrame(min_max_normalized_df_important_attributes_001_007_030, columns = lst_001_007_030)

min_max_normalized_df_important_attributes_030_060_090 = preprocessing.normalize(df_important_attributes_030_060_090)
tmp_030_060_090 = pd.DataFrame(min_max_normalized_df_important_attributes_030_060_090, columns = lst_030_060_090)

# %%
z = np.polyfit(tmp_001_007_0030['total_saved_listings_001'], tmp_001_007_0030['submitted_leads_for_sale_001'], 1)
print(z)
# Out:
# [-0.0089658  0.0010599]

# %%
z = np.polyfit(tmp_001_007_0030['total_saved_listings_007'], tmp_001_007_0030['submitted_leads_for_sale_007'], 1)
print(z)
# Out:
# [-0.0151806   0.00239728]

# %%
z = np.polyfit(tmp_001_007_0030['total_saved_listings_030'], tmp_001_007_0030['submitted_leads_for_sale_030'], 1)
print(z)
# Out:
# [-0.01022282  0.00436348]

# %%
z = np.polyfit(tmp_030_060_090['total_saved_listings_030'], tmp_030_060_090['submitted_leads_for_sale_030'], 1)
print(z)
# Out:
# [-0.01722711  0.00378296]

# %%
z = np.polyfit(tmp_030_060_090['total_saved_listings_060'], tmp_030_060_090['submitted_leads_for_sale_060'], 1)
print(z)
# Out:
# [-0.02742903  0.00448159]

# %%
z = np.polyfit(tmp_030_060_090['total_saved_listings_090'], tmp_030_060_090['submitted_leads_for_sale_090'], 1)
print(z)
# Out:
# [-0.03466869  0.00577188]
